# %%
from IPython.core.display import display
from dharpa_toolbox.modules.core import find_all_module_classes
from dharpa_toolbox.modules.text import CorpusProcessingWorkflow, TokenizeTextModule
from dharpa_toolbox.utils import graph_to_image
from rich.jupyter import print

tsp = TokenizeTextModule()

mcls = find_all_module_classes()

print("====================")

cpw = CorpusProcessingWorkflow()
i = graph_to_image(cpw.execution_graph)
display(i)

print(cpw.input_names)
print(cpw._workflow_outputs)
print(cpw.output_names)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">====================
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #008000">'enable_lowercase'</span>, <span style="color: #008000">'enable_stopwords_removal'</span>, <span style="color: #008000">'file_set'</span>, <span style="color: #008000">'stopwords'</span><span style="font-weight: bold">]</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">{</span>
#     <span style="color: #008000">'processed_text_corpus'</span>:
# ValueLocation<span style="font-weight: bold">(</span><span style="color: #808000">module</span>=<span style="color: #800080">RemoveStopwordsModule</span><span style="font-weight: bold">(</span><span style="color: #808000">id</span>=<span style="color: #008000">'remove_stopwords_from_corpus'</span>
# <span style="color: #808000">input_names</span>=<span style="font-weight: bold">[</span><span style="color: #008000">'enabled'</span>, <span style="color: #008000">'stopwords'</span>, <span style="color: #008000">'text_corpus'</span><span style="font-weight: bold">]</span> <span style="color: #808000">output_names</span>=<span style="font-weight: bold">[</span><span style="color: #008000">'text_corpus'</span><span style="font-weight: bold">])</span> <span style="color: #808000">config</span>=<span style="font-weight: bold">{}</span>,
# <span style="color: #808000">value_name</span>=<span style="color: #008000">'text_corpus'</span>, <span style="color: #808000">type</span>=<span style="font-weight: bold">&lt;</span><span style="color: #ff00ff; font-weight: bold">ValueLocationType.module_output:</span><span style="color: #000000"> </span><span style="color: #000080; font-weight: bold">3</span><span style="font-weight: bold">&gt;)</span>
# <span style="font-weight: bold">}</span>
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"><span style="font-weight: bold">[</span><span style="color: #008000">'processed_text_corpus'</span><span style="font-weight: bold">]</span>
# </pre>
